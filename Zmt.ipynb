# %%
import pandas as pd
import requests
from io import StringIO
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import streamlit as st
import plotly.express as px

# %%
# GitHub CSV URL
github_url = 'https://raw.githubusercontent.com/nethajinirmal13/Training-datasets/main/zomato/zomato.csv'

# Fetch the CSV file from GitHub
response = requests.get(github_url)

# Check if the request was successful
if response.status_code == 200:
    # Read the CSV data from the response
    csv_data = StringIO(response.text)
    
    # Create a DataFrame from the CSV data
    df = pd.read_csv(csv_data)
    
    # Display the DataFrame
    print(df.head())
else:
    print("Failed to retrieve the CSV file from GitHub.")
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# Dictionary mapping country codes to country names
country_names = {
    1: 'India',
    14: 'Australia',
    30: 'Brazil',
    37: 'Canada',
    94: 'Indonesia',
    148: 'New Zealand',
    162: 'Phillipines',
    166: 'Qatar',
    184: 'Singapore',
    189: 'South Africa',
    191: 'Sri Lanka',
    208: 'Turkey',
    214: 'UAE',
    215: 'United Kingdom',
    216: 'United States'
}

# Add a new column "Country Name" based on "Country Code"
df['Country Name'] = df['Country Code'].map(country_names)

print(df)
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml郾 Gurme           208          哿stanbul
# 9547        5908749               Ceviz A埕ac郾           208          哿stanbul
# 9548        5915807                     Huqqa           208          哿stanbul
# 9549        5916112                A侓侓k Kahve           208          哿stanbul
# 9550        5927402  Walter's Coffee Roastery           208          哿stanbul
#
# ...

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# Move the 'Country Name' column to the 2nd index
df.insert(2, 'Country Name', df.pop('Country Name'))

df.head()
# Out:
#    Restaurant ID         Restaurant Name Country Name  Country Code  \
# 0        6317637        Le Petit Souffle  Phillipines           162
# 1        6304287        Izakaya Kikufuji  Phillipines           162
# 2        6300002  Heat - Edsa Shangri-La  Phillipines           162
# 3        6318506                    Ooma  Phillipines           162
# 4        6314302             Sambo Kojin  Phillipines           162
#
#                City                                            Address  \
# 0       Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
# 1       Makati City  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Mandaluyong City  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Mandaluyong City  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Mandaluyong City  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# ...

# %%
# Check unique values of a specific column
unique_values = df['Rating color'].unique()

unique_values
# Out:
# array(['Dark Green', 'Green', 'Yellow', 'Orange', 'White', 'Red'],
#       dtype=object)

# %%
# Check unique values of a specific column
unique_values = df['Rating text'].unique()

unique_values
# Out:
# array(['Excellent', 'Very Good', 'Good', 'Average', 'Not rated', 'Poor'],
#       dtype=object)

# %%
# Select and display only two columns from the DataFrame
selected_columns = df[['Rating color', 'Rating text']]

selected_columns
# Out:
#      Rating color Rating text
# 0      Dark Green   Excellent
# 1      Dark Green   Excellent
# 2           Green   Very Good
# 3      Dark Green   Excellent
# 4      Dark Green   Excellent
# ...           ...         ...
# 9546        Green   Very Good
# 9547        Green   Very Good
# 9548       Yellow        Good
# 9549        Green   Very Good
# 9550        Green   Very Good
#
# [9551 rows x 2 columns]

# %%
# Add a new column 'Currency in Rupees' with 'Rupees' as the currency
df['Currency in Rupees'] = 'Rupees'
# Display the updated DataFrame
df.head()
# Out:
#    Restaurant ID         Restaurant Name Country Name  Country Code  \
# 0        6317637        Le Petit Souffle  Phillipines           162
# 1        6304287        Izakaya Kikufuji  Phillipines           162
# 2        6300002  Heat - Edsa Shangri-La  Phillipines           162
# 3        6318506                    Ooma  Phillipines           162
# 4        6314302             Sambo Kojin  Phillipines           162
#
#                City                                            Address  \
# 0       Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
# 1       Makati City  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Mandaluyong City  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Mandaluyong City  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Mandaluyong City  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Name', 'Country Code',
#        'City', 'Address', 'Locality', 'Locality Verbose', 'Longitude',
#        'Latitude', 'Cuisines', 'Average Cost for two', 'Currency',
#        'Has Table booking', 'Has Online delivery', 'Is delivering now',
#        'Switch to order menu', 'Price range', 'Aggregate rating',
#        'Rating color', 'Rating text', 'Votes', 'Currency in Rupees'],
#       dtype='object')

# %%
df['Currency'].unique()
# Out:
# array(['Botswana Pula(P)', 'Brazilian Real(R$)', 'Dollar($)',
#        'Emirati Diram(AED)', 'Indian Rupees(Rs.)',
#        'Indonesian Rupiah(IDR)', 'NewZealand($)', 'Pounds(專)',
#        'Qatari Rial(QR)', 'Rand(R)', 'Sri Lankan Rupee(LKR)',
#        'Turkish Lira(TL)'], dtype=object)

# %%
# Hypothetical exchange rates relative to Indian Rupee
exchange_rates = {
    'Botswana Pula(P)': 6.08,
    'Brazilian Real(R$)': 16.31,
    'Dollar($)': 83.45,
    'Emirati Diram(AED)': 22.72,
    'Indian Rupees(Rs.)': 1.0,
    'Indonesian Rupiah(IDR)': 0.0052,  
    'NewZealand($)': 49.55,
    'Pounds(專)': 104.15,
    'Qatari Rial(QR)': 22.92,
    'Rand(R)': 4.42,
    'Sri Lankan Rupee(LKR)': 0.28, 
    'Turkish Lira(TL)': 2.58,
}

# Update 'Currency in Rupees' column based on the 'exchange_rates' dictionary
df['Currency in Rupees'] = df['Currency'].map(exchange_rates)

# %%
df['Currency in Rupees']= df['Average Cost for two'] * df['Currency in Rupees']

# %%
df[['Price range','Average Cost for two','Currency','Currency in Rupees']]
# Out:
#       Price range  Average Cost for two          Currency  Currency in Rupees
# 0               3                  1100  Botswana Pula(P)              6688.0
# 1               3                  1200  Botswana Pula(P)              7296.0
# 2               4                  4000  Botswana Pula(P)             24320.0
# 3               4                  1500  Botswana Pula(P)              9120.0
# 4               4                  1500  Botswana Pula(P)              9120.0
# ...           ...                   ...               ...                 ...
# 9546            3                    80  Turkish Lira(TL)               206.4
# 9547            3                   105  Turkish Lira(TL)               270.9
# 9548            4                   170  Turkish Lira(TL)               438.6
# 9549            4                   120  Turkish Lira(TL)               309.6
# 9550            2                    55  Turkish Lira(TL)               141.9
#
# [9551 rows x 4 columns]

# %%
df.columns.unique()
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Name', 'Country Code',
#        'City', 'Address', 'Locality', 'Locality Verbose', 'Longitude',
#        'Latitude', 'Cuisines', 'Average Cost for two', 'Currency',
#        'Has Table booking', 'Has Online delivery', 'Is delivering now',
#        'Switch to order menu', 'Price range', 'Aggregate rating',
#        'Rating color', 'Rating text', 'Votes', 'Currency in Rupees'],
#       dtype='object')

# %%
df
# Out:
#       Restaurant ID           Restaurant Name Country Name  Country Code  \
# 0           6317637          Le Petit Souffle  Phillipines           162
# 1           6304287          Izakaya Kikufuji  Phillipines           162
# 2           6300002    Heat - Edsa Shangri-La  Phillipines           162
# 3           6318506                      Ooma  Phillipines           162
# 4           6314302               Sambo Kojin  Phillipines           162
# ...             ...                       ...          ...           ...
# 9546        5915730               Naml郾 Gurme       Turkey           208
# 9547        5908749               Ceviz A埕ac郾       Turkey           208
# 9548        5915807                     Huqqa       Turkey           208
# 9549        5916112                A侓侓k Kahve       Turkey           208
# 9550        5927402  Walter's Coffee Roastery       Turkey           208
#
#                   City                                            Address  \
# ...

# %%
df.insert(13,'Currency in Rupees',df.pop('Currency in Rupees'))
df
# Out:
#       Restaurant ID           Restaurant Name Country Name  Country Code  \
# 0           6317637          Le Petit Souffle  Phillipines           162
# 1           6304287          Izakaya Kikufuji  Phillipines           162
# 2           6300002    Heat - Edsa Shangri-La  Phillipines           162
# 3           6318506                      Ooma  Phillipines           162
# 4           6314302               Sambo Kojin  Phillipines           162
# ...             ...                       ...          ...           ...
# 9546        5915730               Naml郾 Gurme       Turkey           208
# 9547        5908749               Ceviz A埕ac郾       Turkey           208
# 9548        5915807                     Huqqa       Turkey           208
# 9549        5916112                A侓侓k Kahve       Turkey           208
# 9550        5927402  Walter's Coffee Roastery       Turkey           208
#
#                   City                                            Address  \
# ...

# %%
df['Currency in Rupees'] = '₹' + df['Currency in Rupees'].astype(str)
#df['Currency in Rupees'] = df['Currency in Rupees'].str.replace('₹','')

# %%
#df['Currency in Rupees'] = df['Currency in Rupees'].round(2)

# %%
zomato_df=df
zomato_df
# Out:
#       Restaurant ID           Restaurant Name Country Name  Country Code  \
# 0           6317637          Le Petit Souffle  Phillipines           162
# 1           6304287          Izakaya Kikufuji  Phillipines           162
# 2           6300002    Heat - Edsa Shangri-La  Phillipines           162
# 3           6318506                      Ooma  Phillipines           162
# 4           6314302               Sambo Kojin  Phillipines           162
# ...             ...                       ...          ...           ...
# 9546        5915730               Naml郾 Gurme       Turkey           208
# 9547        5908749               Ceviz A埕ac郾       Turkey           208
# 9548        5915807                     Huqqa       Turkey           208
# 9549        5916112                A侓侓k Kahve       Turkey           208
# 9550        5927402  Walter's Coffee Roastery       Turkey           208
#
#                   City                                            Address  \
# ...

# %%
rating = df.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index()
rating
# Out:
#     Aggregate rating Rating color Rating text     0
# 0                0.0        White   Not rated  2148
# 1                1.8          Red        Poor     1
# 2                1.9          Red        Poor     2
# 3                2.0          Red        Poor     7
# 4                2.1          Red        Poor    15
# 5                2.2          Red        Poor    27
# 6                2.3          Red        Poor    47
# 7                2.4          Red        Poor    87
# 8                2.5       Orange     Average   110
# 9                2.6       Orange     Average   191
# 10               2.7       Orange     Average   250
# 11               2.8       Orange     Average   315
# 12               2.9       Orange     Average   381
# 13               3.0       Orange     Average   468
# 14               3.1       Orange     Average   519
# 15               3.2       Orange     Average   522
# 16               3.3       Orange     Average   483
# ...

# %%
sns.countplot(x='Rating color',data = rating, palette=['Blue','red','orange','yellow','green','darkgreen']) #Hue parameter is used for color
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_14476\1982681743.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Rating color',data = rating, palette=['Blue','red','orange','yellow','green','darkgreen']) #Hue parameter is used for color
# <Axes: xlabel='Rating color', ylabel='count'>

# %%
df['Country Name'].unique()
# Out:
# array(['Phillipines', 'Brazil', 'United States', 'Australia', 'Canada',
#        'Singapore', 'UAE', 'India', 'Indonesia', 'New Zealand',
#        'United Kingdom', 'Qatar', 'South Africa', 'Sri Lanka', 'Turkey'],
#       dtype=object)

# %%
#Create a piechart to show the top city distribution
plt.pie(df['City'].value_counts().values[:5], labels=df['City'].value_counts().index[:5])
# Out:
# ([<matplotlib.patches.Wedge at 0x22771df10d0>,
# ...
#  [Text(-0.6145352824185932, 0.9123301960708633, 'New Delhi'),
#   Text(0.0623675251198054, -1.0982305276263407, 'Gurgaon'),
#   Text(0.8789045225625368, -0.6614581167535246, 'Noida'),
#   Text(1.0922218418223437, -0.13058119407559224, 'Faridabad'),
#   Text(1.099946280005612, -0.010871113182029924, 'Ghaziabad')])

# %%
#Piechart for most ordered cuisines (TOP 10)

plt.pie(df['Cuisines'].value_counts().values[:10], labels=df['Cuisines'].value_counts().index[:10],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22771ec1c10>,
# ...
#  [Text(0.7383739846958008, 0.8153550507137645, 'North Indian'),
#   Text(-0.5794679314239953, 0.9349956772366362, 'North Indian, Chinese'),
#   Text(-1.067309479615702, 0.26617752482593154, 'Chinese'),
#   Text(-1.0185984499802057, -0.4152796620326146, 'Fast Food'),
#   Text(-0.5935788454809928, -0.9261015895664211, 'North Indian, Mughlai'),
#   Text(-0.005887079599915552, -1.0999842463843672, 'Cafe'),
#   Text(0.4842062514572988, -0.9876964645323336, 'Bakery'),
#   Text(0.808736477166136, -0.7456174022251013, 'North Indian, Mughlai, Chinese'),
#   Text(1.0055375294202338, -0.44597564611473206, 'Bakery, Desserts'),
#   Text(1.090298995560443, -0.14576728123927227, 'Street Food')],
#  [Text(0.4027494461977095, 0.4447391185711442, '26.58%'),
#   Text(-0.316073417140361, 0.5099976421290743, '14.51%'),
#   Text(-0.5821688070631101, 0.14518774081414446, '10.05%'),
#   Text(-0.5555991545346576, -0.22651617929051704, '10.05%'),
# ...

# %%
# Filter the dataframe to get data where the country name is India
indian_data = df[df['Country Name'] == 'India']

# Display the filtered data
indian_data.head()
# Out:
#      Restaurant ID                        Restaurant Name Country Name  \
# 624        3400025                             Jahanpanah        India
# 625        3400341                    Rangrezz Restaurant        India
# 626        3400005                Time2Eat - Mama Chicken        India
# 627        3400021  Chokho Jeeman Marwari Jain Bhojanalya        India
# 628        3400017                         Pinch Of Spice        India
#
#      Country Code  City                                            Address  \
# 624             1  Agra  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...
# 625             1  Agra  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...
# 626             1  Agra        Main Market, Sadar Bazaar, Agra Cantt, Agra
# 627             1  Agra  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...
# 628             1  Agra  23/453, Opposite Sanjay Cinema, Wazipura Road,...
#
#         Locality   Locality Verbose  Longitude   Latitude  ...  \
# ...

# %%
dfx=indian_data[['Has Table booking','Has Online delivery','Is delivering now','Switch to order menu']].value_counts()
dfx
# Out:
# Has Table booking  Has Online delivery  Is delivering now  Switch to order menu
# No                 No                   No                 No                      5545
#                    Yes                  No                 No                      1963
# Yes                No                   No                 No                       684
#                    Yes                  No                 No                       426
# No                 Yes                  Yes                No                        33
# Yes                Yes                  Yes                No                         1
# Name: count, dtype: int64

# %%
currency_comparison = px.scatter(df, x='Currency in Rupees', y='Country Code', color='Country Name',
                                 title='Comparison of Indian Currency with Other Countries')
#st.plotly_chart(currency_comparison)
currency_comparison.show()

# %%
sns.barplot(df, x='Currency in Rupees', y='Country Code', color='Country Name',title='Comparison of Indian Currency with Other Countries')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 sns.barplot(df, x='Currency in Rupees', y='Country Code', color='Country Name',title='Comparison of Indian Currency with Other Countries')
#
# File c:\Users\ADMIN\Desktop\New1folder\venv\Lib\site-packages\seaborn\categorical.py:2371, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2369 saturation = saturation if fill else 1
#    2370 p.map_hue(palette=palette, order=hue_order, norm=hue_norm, saturation=saturation)
# -> 2371 color = _default_color(ax.bar, hue, color, kwargs, saturation=saturation)
# ...
